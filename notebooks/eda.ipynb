# %%
# %load_ext autoreload
# %autoreload 2

from usopen.data import load_matches
from usopen.paths import MATCHES_CSV

df = load_matches(MATCHES_CSV)
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68591 entries, 0 to 68590
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tournament   68591 non-null  str
#  1   Date         68591 non-null  datetime64[us]
#  2   Series       68591 non-null  str
#  3   Court        68591 non-null  str
#  4   Surface      68591 non-null  str
#  5   Round        68591 non-null  str
#  6   Best of      68591 non-null  int64
#  7   Player_1     68591 non-null  str
#  8   Player_2     68591 non-null  str
#  9   Winner       68591 non-null  str
#  10  Rank_1       68577 non-null  float64
#  11  Rank_2       68579 non-null  float64
#  12  Pts_1        52939 non-null  float64
#  13  Pts_2        52938 non-null  float64
#  14  Odd_1        64809 non-null  float64
#  15  Odd_2        64811 non-null  float64
#  16  Score        68591 non-null  str
#  17  round_order  68591 non-null  int64
# ...

# %%
df_2018 = df.loc[df["Date"] >= "2018-01-01"]

# %%
print(len(df))          # до фильтра
print(len(df_2018))     # после
# Out:
# 68591
# 20879

# %%
df_2018["Series"].value_counts()
df_gaps = (df_2018["Winner"] == df_2018["Player_1"]).mean()
df_asc_sorting = (df_2018["Player_1"] <= df_2018["Player_2"]).mean()

df_train = df.loc[df["Date"] < "2025-01-01"]
df_val = df.loc[(df["Date"] >= "2025-01-01") & (df["Date"] < "2026-01-01")]
df_test = df.loc[df["Date"] >= "2026-01-01"]
print(df_gaps)
print(df_asc_sorting)
print(len(df_train))
print(len(df_val))
print(len(df_test))
# Out:
# 0.5000239475070645
# 0.49810814694190336
# 64193
# 2487
# 1911

# %%
print(df['Round'].value_counts())
# Out:
# Round
# 1st Round        31379
# 2nd Round        19154
# Quarterfinals     6482
# 3rd Round         4859
# Semifinals        3314
# The Final         1683
# 4th Round         1294
# Round Robin        426
# Name: count, dtype: int64

# %%
print(df['Series'].value_counts())
# Out:
# Series
# ATP250                18268
# Grand Slam            12871
# International         11752
# Masters 1000           9827
# ATP500                 6837
# Masters                5029
# International Gold     3620
# Masters Cup             387
# Name: count, dtype: int64
